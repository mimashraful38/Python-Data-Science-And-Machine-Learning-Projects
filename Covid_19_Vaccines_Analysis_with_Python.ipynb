# %% [markdown]
# <a href="https://colab.research.google.com/github/mimashraful38/Data-Science-And-Machine-Learning-Projects/blob/main/Covid_19_Vaccines_Analysis_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/country_vaccinations.csv')

# %%
data.head()
# Out:
#        country  ...                                     source_website
# 0  Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 1  Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 2  Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 3  Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
# 4  Afghanistan  ...  http://www.xinhuanet.com/english/asiapacific/2...
#
# [5 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# country                                   0
# iso_code                                  0
# date                                      0
# total_vaccinations                     4329
# people_vaccinated                      4836
# people_fully_vaccinated                6393
# daily_vaccinations_raw                 5376
# daily_vaccinations                      186
# total_vaccinations_per_hundred         4329
# people_vaccinated_per_hundred          4836
# people_fully_vaccinated_per_hundred    6393
# daily_vaccinations_per_million          186
# vaccines                                  0
# source_name                               1
# source_website                            1
# dtype: int64

# %%
data.describe()
# Out:
#        total_vaccinations  ...  daily_vaccinations_per_million
# count        6.327000e+03  ...                    10470.000000
# mean         2.703496e+06  ...                     2827.267240
# std          1.111672e+07  ...                     5044.207507
# min          0.000000e+00  ...                        0.000000
# 25%          4.692850e+04  ...                      356.250000
# 50%          3.058800e+05  ...                     1387.500000
# 75%          1.331121e+06  ...                     3428.000000
# max          1.873600e+08  ...                   118759.000000
#
# [8 rows x 9 columns]

# %%
pd.to_datetime(data.date)
# Out:
# 0       2021-02-22
# 1       2021-02-23
# 2       2021-02-24
# 3       2021-02-25
# 4       2021-02-26
#            ...
# 10651   2021-04-15
# 10652   2021-04-16
# 10653   2021-01-28
# 10654   2021-01-29
# 10655   2021-01-30
# Name: date, Length: 10656, dtype: datetime64[ns]

# %%
data.country.value_counts()
# Out:
# Canada       124
# China        123
# Russia       123
# Israel       119
# Qatar        116
#             ...
# Cameroon       2
# Laos           1
# Nicaragua      1
# Ethiopia       1
# Armenia        1
# Name: country, Length: 158, dtype: int64

# %%
data = data[data.country.apply(lambda x: x not in ["England", "Scotland", "Wales", "Northern Ireland"])]
data.country.value_counts()
# Out:
# Canada       124
# Russia       123
# China        123
# Israel       119
# Qatar        116
#             ...
# Cameroon       2
# Nicaragua      1
# Laos           1
# Ethiopia       1
# Armenia        1
# Name: country, Length: 155, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                  2772
# Oxford/AstraZeneca                                                            1599
# Pfizer/BioNTech                                                               1257
# Oxford/AstraZeneca, Pfizer/BioNTech                                            748
# Moderna, Pfizer/BioNTech                                                       395
# Pfizer/BioNTech, Sinovac                                                       373
# Sputnik V                                                                      325
# Oxford/AstraZeneca, Sinovac                                                    288
# Oxford/AstraZeneca, Sinopharm/Beijing                                          281
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V              277
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                               248
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                   235
# Pfizer/BioNTech, Sinopharm/Beijing                                             227
# Sinopharm/Beijing                                                              176
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                    123
# EpiVacCorona, Sputnik V                                                        123
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V               114
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V     108
# Covaxin, Oxford/AstraZeneca                                                     92
# Moderna, Oxford/AstraZeneca                                                     91
# Sinovac                                                                         90
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                          74
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac                                  67
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                  58
# Johnson&Johnson                                                                 57
# Sinopharm/Beijing, Sputnik V                                                    57
# Pfizer/BioNTech, Sputnik V                                                      48
# Oxford/AstraZeneca, Sputnik V                                                   43
# Oxford/AstraZ                                                                    1
# Name: vaccines, dtype: int64

# %%
df = data[["vaccines", "country"]]

# %%
df
# Out:
#                                            vaccines      country
# 0                                Oxford/AstraZeneca  Afghanistan
# 1                                Oxford/AstraZeneca  Afghanistan
# 2                                Oxford/AstraZeneca  Afghanistan
# 3                                Oxford/AstraZeneca  Afghanistan
# 4                                Oxford/AstraZeneca  Afghanistan
# ...                                             ...          ...
# 10651  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech        Spain
# 10652  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech        Spain
# 10653                            Oxford/AstraZeneca    Sri Lanka
# 10654                            Oxford/AstraZeneca    Sri Lanka
# 10655                                 Oxford/AstraZ    Sri Lanka
#
# [10347 rows x 2 columns]

# %%
dict_ = {}
for i in df.vaccines.unique():
  dict_[i] = [df["country"][j] for j in df[df["vaccines"]==i].index]

vaccines = {}
for key, value in dict_.items():
  vaccines[key] = set(value)
for i, j in vaccines.items():
  print(f"{i}:>>{j}")
# Out:
# Oxford/AstraZeneca:>>{"Cote d'Ivoire", 'Anguilla', 'Georgia', 'Sao Tome and Principe', 'Falkland Islands', 'Bhutan', 'Bahamas', 'Belize', 'Kosovo', 'Saint Lucia', 'Sierra Leone', 'Bangladesh', 'Eswatini', 'Grenada', 'Papua New Guinea', 'Saint Kitts and Nevis', 'Cape Verde', 'Saint Helena', 'Mauritius', 'Ghana', 'Botswana', 'South Sudan', 'Nepal', 'Fiji', 'Antigua and Barbuda', 'Ethiopia', 'Sri Lanka', 'Mali', 'Malawi', 'Moldova', 'Mongolia', 'Angola', 'Brunei', 'Myanmar', 'Gambia', 'Solomon Islands', 'Saint Vincent and the Grenadines', 'Jamaica', 'Afghanistan', 'Guyana', 'Dominica', 'Nigeria', 'Barbados', 'Montserrat'}
# Pfizer/BioNTech, Sinovac:>>{'Hong Kong', 'Colombia', 'Malaysia', 'Chile', 'Albania'}
# Sputnik V:>>{'Algeria', 'Armenia', 'Kazakhstan', 'Paraguay', 'Guinea', 'Iran', 'Belarus'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Slovenia', 'Guernsey', 'Andorra', 'Australia', 'Saudi Arabia', 'South Korea', 'Jersey', 'Oman', 'Isle of Man'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V:>>{'Argentina', 'Pakistan', 'Bolivia'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech:>>{'Czechia', 'Spain', 'Finland', 'Malta', 'France', 'Poland', 'Belgium', 'Rwanda', 'Norway', 'Portugal', 'Luxembourg', 'Romania', 'Croatia', 'Austria', 'Italy', 'Estonia', 'Latvia', 'Iceland', 'Germany', 'Ireland', 'Canada', 'Greece', 'Lithuania', 'Denmark', 'Palestine', 'Bulgaria', 'Netherlands'}
# Sinovac:>>{'Azerbaijan'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Serbia', 'Lebanon', 'Bahrain'}
# Pfizer/BioNTech:>>{'Cyprus', 'New Zealand', 'Gibraltar', 'Kuwait', 'Panama', 'Slovakia', 'Costa Rica', 'Cayman Islands', 'Greenland', 'Japan', 'Monaco', 'Qatar', 'Bermuda', 'North Macedonia'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V:>>{'Bosnia and Herzegovina'}
# Oxford/AstraZeneca, Sinovac:>>{'Brazil', 'Philippines', 'Dominican Republic', 'Indonesia'}
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac:>>{'Cambodia'}
# Sinopharm/Beijing:>>{'Gabon', 'Cameroon', 'Namibia', 'Equatorial Guinea', 'Kyrgyzstan', 'Mauritania', 'Senegal', 'Mozambique'}
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac:>>{'China'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac:>>{'Ecuador', 'El Salvador', 'Northern Cyprus'}
# Oxford/AstraZeneca, Sinopharm/Beijing:>>{'Seychelles', 'Egypt', 'Morocco', 'Iraq'}
# Moderna, Pfizer/BioNTech:>>{'Faeroe Islands', 'Singapore', 'Liechtenstein', 'Israel'}
# Moderna, Oxford/AstraZeneca:>>{'Honduras', 'Guatemala'}
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V:>>{'Hungary'}
# Covaxin, Oxford/AstraZeneca:>>{'India'}
# Pfizer/BioNTech, Sinopharm/Beijing:>>{'Peru', 'Jordan', 'Macao'}
# Oxford/AstraZeneca, Sputnik V:>>{'Kenya', 'Nicaragua'}
# Sinopharm/Beijing, Sputnik V:>>{'Montenegro', 'Laos'}
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing:>>{'Maldives'}
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V:>>{'Mexico'}
# EpiVacCorona, Sputnik V:>>{'Russia'}
# Pfizer/BioNTech, Sputnik V:>>{'San Marino'}
# Johnson&Johnson:>>{'South Africa'}
# Oxford/AstraZ:>>{'Sri Lanka'}

# %%
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":1,"t":1,"l":1,"b":1})
vaccine_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a5c68306-d1b0-4d17-b1cf-832e028cfe40" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a5c68306-d1b0-4d17-b1cf-832e028cfe40")) {
#                     Plotly.newPlot(
#                         'a5c68306-d1b0-4d17-b1cf-832e028cfe40',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "iso_code=%{location}<br>vaccines=%{z}", "locations": ["AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "AFG", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "ALB", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "DZA", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AND", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AGO", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "AIA", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ATG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARG", "ARM", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "AUS",  ...
