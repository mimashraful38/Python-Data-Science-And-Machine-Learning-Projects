# %% [markdown]
# <a href="https://colab.research.google.com/github/mimashraful38/Mine-VS-Rocks/blob/main/Mine_VS_Rocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mine vs Rock

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('/content/sonar.all-data.csv', header=None)
data.head()
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117   R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
data.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
data.shape
# Out:
# (208, 61)

# %%
data.describe()
# Out:
#                0           1           2   ...          57          58          59
# count  208.000000  208.000000  208.000000  ...  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832  ...    0.007949    0.007941    0.006507
# std      0.022991    0.032960    0.038428  ...    0.006470    0.006181    0.005031
# min      0.001500    0.000600    0.001500  ...    0.000300    0.000100    0.000600
# 25%      0.013350    0.016450    0.018950  ...    0.003600    0.003675    0.003100
# 50%      0.022800    0.030800    0.034300  ...    0.005800    0.006400    0.005300
# 75%      0.035550    0.047950    0.057950  ...    0.010350    0.010325    0.008525
# max      0.137100    0.233900    0.305900  ...    0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
x=data.loc[: ,:59]
y=data.loc[:,60]

# %%
x
# Out:
#          0       1       2       3   ...      56      57      58      59
# 0    0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 1    0.0453  0.0523  0.0843  0.0689  ...  0.0140  0.0049  0.0052  0.0044
# 2    0.0262  0.0582  0.1099  0.1083  ...  0.0316  0.0164  0.0095  0.0078
# 3    0.0100  0.0171  0.0623  0.0205  ...  0.0050  0.0044  0.0040  0.0117
# 4    0.0762  0.0666  0.0481  0.0394  ...  0.0072  0.0048  0.0107  0.0094
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 204  0.0323  0.0101  0.0298  0.0564  ...  0.0034  0.0032  0.0062  0.0067
# 205  0.0522  0.0437  0.0180  0.0292  ...  0.0140  0.0138  0.0077  0.0031
# 206  0.0303  0.0353  0.0490  0.0608  ...  0.0034  0.0079  0.0036  0.0048
# 207  0.0260  0.0363  0.0136  0.0272  ...  0.0040  0.0036  0.0061  0.0115
#
# [208 rows x 60 columns]

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
x_train, x_test,y_train,y_test= train_test_split(x,y, test_size=0.1, random_state=1)

# %%
x_train.shape
# Out:
# (187, 60)

# %%
x_test.shape
# Out:
# (21, 60)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (187,)
# (21,)

# %%
x_train
# Out:
#          0       1       2       3   ...      56      57      58      59
# 59   0.0125  0.0152  0.0218  0.0175  ...  0.0017  0.0041  0.0086  0.0058
# 29   0.0189  0.0308  0.0197  0.0622  ...  0.0099  0.0092  0.0052  0.0075
# 11   0.0123  0.0309  0.0169  0.0313  ...  0.0026  0.0092  0.0009  0.0044
# 124  0.0388  0.0324  0.0688  0.0898  ...  0.0107  0.0068  0.0097  0.0067
# 147  0.0654  0.0649  0.0737  0.1132  ...  0.0355  0.0440  0.0243  0.0098
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  ...  0.0065  0.0115  0.0193  0.0157
# 137  0.0430  0.0902  0.0833  0.0813  ...  0.0027  0.0162  0.0059  0.0021
# 72   0.0208  0.0186  0.0131  0.0211  ...  0.0028  0.0019  0.0049  0.0023
# 140  0.0412  0.1135  0.0518  0.0232  ...  0.0095  0.0225  0.0098  0.0085
# 37   0.0333  0.0221  0.0270  0.0481  ...  0.0143  0.0132  0.0051  0.0041
#
# [187 rows x 60 columns]

# %%
y_train
# Out:
# 59     R
# 29     R
# 11     R
# 124    M
# 147    M
#       ..
# 203    M
# 137    M
# 72     R
# 140    M
# 37     R
# Name: 60, Length: 187, dtype: object

# %%
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
x_pre=model.predict(x_train)
accuracy_score(x_pre, y_train)
# Out:
# 0.8556149732620321

# %%
x_per=model.predict(x_test)
accuracy_score(x_per,y_test)
# Out:
# 0.7142857142857143

# %%
input_data = (0.0164,	0.0173	,0.0347,	0.007,	0.0187	,0.0671,	0.1056,	0.0697	,0.0962	,0.0251	,0.0801,	0.1056,	0.1266	,0.089,	0.0198,	0.1133	,0.2826,	0.3234	,0.3238,	0.4333,	0.6068	,0.7652	,0.9203	,0.9719	,0.9207	,0.7545,	0.8289,	0.8907	,0.7309	,0.6896,0.5829	,0.4935,	0.3101	,0.0306,	0.0244,	0.1108,	0.1594,	0.1371,0.0696,	0.0452,	0.062,	0.1421	,0.1597,	0.1384,	0.0372,	0.0688	,0.0867,	0.0513,	0.0092,	0.0198	,0.0118	,0.009	,0.0223	,0.0179,	0.0084,	0.0068	,0.0032,	0.0035,	0.0056,	0.004)

# changing the input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]=='R'):
  print('The object is a Rock')
else:
  print('The object is a mine')
# Out:
# ['R']
# The object is a Rock
